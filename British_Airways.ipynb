# %% [markdown]
# <a href="https://colab.research.google.com/github/rida-manzoor/Bristish-Airways-/blob/main/British_Airways.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1
#
# ---
#
# ## Web scraping and analysis
#
# This Jupyter notebook includes some code to get you started with web scraping. We will use a package called `BeautifulSoup` to collect the data from the web. Once you've collected your data and saved it into a local `.csv` file you should start with your analysis.
#
# ### Scraping data from Skytrax
#
# If you visit [https://www.airlinequality.com] you can see that there is a lot of data there. For this task, we are only interested in reviews related to British Airways and the Airline itself.
#
# If you navigate to this link: [https://www.airlinequality.com/airline-reviews/british-airways] you will see this data. Now, we can use `Python` and `BeautifulSoup` to collect all the links to the reviews and then to collect the text data on each of the individual review links.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "https://www.airlinequality.com/airline-reviews/british-airways"
pages = 25
page_size = 100

reviews = []

# for i in range(1, pages + 1):
for i in range(1, pages + 1):

    print(f"Scraping page {i}")

    # Create URL to collect links from paginated data
    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"

    # Collect HTML data from this page
    response = requests.get(url)

    # Parse content
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    for para in parsed_content.find_all("div", {"class": "text_content"}):
        reviews.append(para.get_text())

    print(f"   ---> {len(reviews)} total reviews")
# Out:
# Scraping page 1
#    ---> 100 total reviews
# Scraping page 2
#    ---> 200 total reviews
# Scraping page 3
#    ---> 300 total reviews
# Scraping page 4
#    ---> 400 total reviews
# Scraping page 5
#    ---> 500 total reviews
# Scraping page 6
#    ---> 600 total reviews
# Scraping page 7
#    ---> 700 total reviews
# Scraping page 8
#    ---> 800 total reviews
# Scraping page 9
#    ---> 900 total reviews
# Scraping page 10
#    ---> 1000 total reviews
# Scraping page 11
#    ---> 1100 total reviews
# Scraping page 12
#    ---> 1200 total reviews
# Scraping page 13
#    ---> 1300 total reviews
# Scraping page 14
#    ---> 1400 total reviews
# Scraping page 15
#    ---> 1500 total reviews
# Scraping page 16
#    ---> 1600 total reviews
# Scraping page 17
#    ---> 1700 total reviews
# Scraping page 18
#    ---> 1800 total reviews
# Scraping page 19
#    ---> 1900 total reviews
# Scraping page 20
#    ---> 2000 total reviews
# Scraping page 21
#    ---> 2100 total reviews
# ...

# %%
df = pd.DataFrame()
df["reviews"] = reviews
df.head()
# Out:
#                                              reviews
# 0  ✅ Trip Verified | We had possibly the worse ch...
# 1  ✅ Trip Verified |  I flew to LHR from ATH in C...
# 2  ✅ Trip Verified |  I like the British Airways ...
# 3  ✅ Trip Verified |  I have come to boarding and...
# 4  ✅ Trip Verified | Stinking nappies being chang...

# %%
df.to_csv("data/BA_reviews.csv")

# %% [markdown]
# ## Data Preprocessing

# %%
df = pd.read_csv('data/BA_reviews.csv')
df
# Out:
#       Unnamed: 0                                            reviews
# 0              0  ✅ Trip Verified | We had possibly the worse ch...
# 1              1  ✅ Trip Verified |  I flew to LHR from ATH in C...
# 2              2  ✅ Trip Verified |  I like the British Airways ...
# 3              3  ✅ Trip Verified |  I have come to boarding and...
# 4              4  ✅ Trip Verified | Stinking nappies being chang...
# ...          ...                                                ...
# 2495        2495  Late evening departure on BA28 from Hong Kong ...
# 2496        2496  Club class on British Airways between Cape Tow...
# 2497        2497  Just returned from Orlando to London via Miami...
# 2498        2498  London to San Francisco with British Airways w...
# 2499        2499  Copenhagen to London on a very full plane, wit...
#
# [2500 rows x 2 columns]

# %%
# Drop the 'Unnamed' column
df = df.drop(columns=['Unnamed: 0'])

df
# Out:
#                                                 reviews
# 0     ✅ Trip Verified | We had possibly the worse ch...
# 1     ✅ Trip Verified |  I flew to LHR from ATH in C...
# 2     ✅ Trip Verified |  I like the British Airways ...
# 3     ✅ Trip Verified |  I have come to boarding and...
# 4     ✅ Trip Verified | Stinking nappies being chang...
# ...                                                 ...
# 2495  Late evening departure on BA28 from Hong Kong ...
# 2496  Club class on British Airways between Cape Tow...
# 2497  Just returned from Orlando to London via Miami...
# 2498  London to San Francisco with British Airways w...
# 2499  Copenhagen to London on a very full plane, wit...
#
# [2500 rows x 1 columns]

# %% [markdown]
# ### Topic Modelling

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download NLTK resources if not already downloaded
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Assuming 'reviews' is the column containing text reviews
df['reviews'] = df['reviews'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in word_tokenize(x.lower()) if word.isalnum() and word not in stop_words]))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df
# Out:
#       Unnamed: 0                                            reviews
# 0              0  trip verified possibly worse experience ever e...
# 1              1  trip verified flew lhr ath club europe ba641 d...
# 2              2  trip verified like british airway world travel...
# 3              3  trip verified come boarding cabin luggage take...
# 4              4  trip verified stinking nappy changed business ...
# ...          ...                                                ...
# 2495        2495  late evening departure ba28 hong kong heathrow...
# 2496        2496  club class british airway cape town london boe...
# 2497        2497  returned orlando london via miami booked direc...
# 2498        2498  london san francisco british airway pleasant e...
# 2499        2499  copenhagen london full plane british airway st...
#
# [2500 rows x 2 columns]

# %%
from gensim import corpora, models
import pandas as pd


# Create a dictionary and a corpus
dictionary = corpora.Dictionary(df['reviews'].apply(str.split))
corpus = [dictionary.doc2bow(text) for text in df['reviews'].apply(str.split)]

# Train the LDA model
lda_model = models.LdaModel(corpus, num_topics=7, id2word=dictionary, passes=15)

# Extract topics and their weights
topics_data = []
for topic_num, words in lda_model.print_topics(num_words=9):
    topics_data.append({'TopicNum': topic_num, 'Words': words})

# Create a DataFrame with topics information
topics_df = pd.DataFrame(topics_data)

# Map topic numbers to meaningful labels
topic_labels = {
    0: "Label0",
    1: "Label1",
    2: "Label2",
    3: "Label3",
    4: "Label4",
    5: "Label5",
    6: "Label6"
}

topics_df['TopicLabel'] = topics_df['TopicNum'].map(topic_labels)

# Rename columns for better readability
topics_df = topics_df.rename(columns={'TopicNum': 'TopicNumber', 'Words': 'TopWords'})

# Display the DataFrame with topics and labels
print(topics_df)
# Out:
#    TopicNumber                                           TopWords TopicLabel
# 0            0  0.015*"seat" + 0.010*"child" + 0.009*"stroller...     Label0
# 1            1  0.009*"spain" + 0.007*"aviv" + 0.007*"tel" + 0...     Label1
# 2            2  0.002*"temerity" + 0.002*"temp" + 0.002*"hazar...     Label2
# 3            3  0.029*"flight" + 0.020*"ba" + 0.010*"hour" + 0...     Label3
# 4            4  0.024*"seat" + 0.010*"lounge" + 0.009*"breakfa...     Label4
# 5            5  0.041*"flight" + 0.017*"time" + 0.014*"crew" +...     Label5
# 6            6  0.019*"flight" + 0.018*"seat" + 0.014*"ba" + 0...     Label6

# %%
print(topics_df['TopWords'][6])
# Out:
# 0.019*"flight" + 0.018*"seat" + 0.014*"ba" + 0.011*"food" + 0.010*"service" + 0.010*"cabin" + 0.009*"class" + 0.009*"crew" + 0.009*"airway"

# %%
# Create a mapping dictionary for the new topic labels
new_topic_labels = {
    0: "Traveling with Children and Seating Comfort",
    1: "International Travel Documentation and Gate Procedures",
    2: "Operational and Technical Aspects of Air Travel",
    3: "Flight Duration and Customer Service Experience",
    4: "Seating Comfort and Lounge Experience",
    5: "Punctuality, Crew Performance, and Heathrow Experience",
    6: "In-Flight Experience and Service Quality"


}

# Update the 'TopicLabel' column in topics_df
topics_df['TopicLabel'] = topics_df['TopicNumber'].map(new_topic_labels)

# Display the updated DataFrame
print(topics_df)
# Out:
#    TopicNumber                                           TopWords  \
# 0            0  0.015*"seat" + 0.010*"child" + 0.009*"stroller...
# 1            1  0.009*"spain" + 0.007*"aviv" + 0.007*"tel" + 0...
# 2            2  0.002*"temerity" + 0.002*"temp" + 0.002*"hazar...
# 3            3  0.029*"flight" + 0.020*"ba" + 0.010*"hour" + 0...
# 4            4  0.024*"seat" + 0.010*"lounge" + 0.009*"breakfa...
# 5            5  0.041*"flight" + 0.017*"time" + 0.014*"crew" +...
# 6            6  0.019*"flight" + 0.018*"seat" + 0.014*"ba" + 0...
#
#                                           TopicLabel
# 0        Traveling with Children and Seating Comfort
# 1  International Travel Documentation and Gate Pr...
# 2    Operational and Technical Aspects of Air Travel
# 3    Flight Duration and Customer Service Experience
# 4              Seating Comfort and Lounge Experience
# 5  Punctuality, Crew Performance, and Heathrow Ex...
# 6           In-Flight Experience and Service Quality

# %%
topics_df
# Out:
#    TopicNumber                                           TopWords  \
# 0            0  0.015*"seat" + 0.010*"child" + 0.009*"stroller...
# 1            1  0.009*"spain" + 0.007*"aviv" + 0.007*"tel" + 0...
# 2            2  0.002*"temerity" + 0.002*"temp" + 0.002*"hazar...
# 3            3  0.029*"flight" + 0.020*"ba" + 0.010*"hour" + 0...
# 4            4  0.024*"seat" + 0.010*"lounge" + 0.009*"breakfa...
# 5            5  0.041*"flight" + 0.017*"time" + 0.014*"crew" +...
# 6            6  0.019*"flight" + 0.018*"seat" + 0.014*"ba" + 0...
#
#                                           TopicLabel
# 0        Traveling with Children and Seating Comfort
# 1  International Travel Documentation and Gate Pr...
# 2    Operational and Technical Aspects of Air Travel
# 3    Flight Duration and Customer Service Experience
# 4              Seating Comfort and Lounge Experience
# 5  Punctuality, Crew Performance, and Heathrow Ex...
# 6           In-Flight Experience and Service Quality

# %% [markdown]
# ### Explore Topic Distributions

# %%
df
# Out:
#       Unnamed: 0                                            reviews
# 0              0  trip verified possibly worse experience ever e...
# 1              1  trip verified flew lhr ath club europe ba641 d...
# 2              2  trip verified like british airway world travel...
# 3              3  trip verified come boarding cabin luggage take...
# 4              4  trip verified stinking nappy changed business ...
# ...          ...                                                ...
# 2495        2495  late evening departure ba28 hong kong heathrow...
# 2496        2496  club class british airway cape town london boe...
# 2497        2497  returned orlando london via miami booked direc...
# 2498        2498  london san francisco british airway pleasant e...
# 2499        2499  copenhagen london full plane british airway st...
#
# [2500 rows x 2 columns]

# %%
topics_df
# Out:
#    TopicNumber                                           TopWords  \
# 0            0  0.015*"seat" + 0.010*"child" + 0.009*"stroller...
# 1            1  0.009*"spain" + 0.007*"aviv" + 0.007*"tel" + 0...
# 2            2  0.002*"temerity" + 0.002*"temp" + 0.002*"hazar...
# 3            3  0.029*"flight" + 0.020*"ba" + 0.010*"hour" + 0...
# 4            4  0.024*"seat" + 0.010*"lounge" + 0.009*"breakfa...
# 5            5  0.041*"flight" + 0.017*"time" + 0.014*"crew" +...
# 6            6  0.019*"flight" + 0.018*"seat" + 0.014*"ba" + 0...
#
#                                           TopicLabel
# 0        Traveling with Children and Seating Comfort
# 1  International Travel Documentation and Gate Pr...
# 2    Operational and Technical Aspects of Air Travel
# 3    Flight Duration and Customer Service Experience
# 4              Seating Comfort and Lounge Experience
# 5  Punctuality, Crew Performance, and Heathrow Ex...
# 6           In-Flight Experience and Service Quality

# %%
selected_label = 'Traveling with Children and Seating Comfort'  # Replace with the actual label you want to explore
selected_label_df = topics_df[topics_df['TopicLabel'] == selected_label]

# %%
word_to_count = 'flight'  # Replace with the actual word you want to count

selected_label_df.loc[:, 'word_count'] = df['reviews'].str.count(word_to_count)
# Out:
# <ipython-input-54-786d38b8379f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_label_df.loc[:, 'word_count'] = df['reviews'].str.count(word_to_count)

# %%
selected_label_df
# Out:
#    TopicNumber                                           TopWords  \
# 0            0  0.015*"seat" + 0.010*"child" + 0.009*"stroller...
#
#                                     TopicLabel  word_count
# 0  Traveling with Children and Seating Comfort           1
